# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv('dataset.csv')

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.shape
# Out:
# (506, 14)

# %% [markdown]
# ### Exploratory data analysis

# %%
df.isnull().sum()    #checking if dataset contains null values
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560262   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX          int64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %% [markdown]
# ### Replacing missing values

# %%
df['CRIM'].fillna(value = df['CRIM'].median(),inplace = True)

# %%
plt.style.use('ggplot')

# %%
plt.hist(df['CRIM'],bins = 10,color = 'green')
plt.xlabel('CRIM')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df['ZN'].fillna(value = df['ZN'].mode()[0],inplace = True)

# %%
plt.hist(df['ZN'],bins = 10,color = 'blue')
plt.xlabel('ZN')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df['INDUS'].fillna(value = df['INDUS'].mean(), inplace = True)

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.hist(df['INDUS'],bins = 10,color = 'magenta')
plt.xlabel('INDUS')
plt.ylabel('COUNT')

plt.subplot(1,2,2)
plt.boxplot(df['INDUS'])
plt.xlabel('INDUS')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df['CHAS'].fillna(value = df['CHAS'].mode()[0], inplace = True)

# %%
sns.countplot(x='CHAS',data=df)
# Out:
# <AxesSubplot:xlabel='CHAS', ylabel='count'>

# %%
df['AGE'].fillna(value = df['AGE'].mean(), inplace = True)

# %%
plt.hist(df['AGE'],bins = 10,color = 'skyblue')
plt.xlabel('AGE')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df['LSTAT'].fillna(value = df['LSTAT'].mean(), inplace = True)

# %%
plt.hist(df['LSTAT'],bins = 30,color = 'blue')
plt.xlabel('LSTAT')
plt.ylabel('COUNT')
# Out:
# Text(0, 0.5, 'COUNT')

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# ### Data Visualization

# %%
# Correlation between Different features
correlation_matrix = df.corr().round(2)
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix,annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# We can see from the heatmap that the variable 'RM' has highest correlation with price 'MEDV'

# %%
# Plotting 'RM' with 'MEDV'
print(sns.jointplot(x='RM',y='MEDV',data=df,kind="hex",color = 'blue'))

# %% [markdown]
# the variable 'LSTAT' has lowest correlation with price 'MEDV'

# %%
# Plotting 'LSTAT' with 'MEDV'
sns.jointplot(x='LSTAT',y='MEDV',data=df,kind="reg",color = 'blue')

# %%
# Distributing of Price Column
sns.distplot(df['MEDV'],color = 'blue')
# Out:
# D:\ANACONDA\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MEDV', ylabel='Density'>

# %% [markdown]
# ### Training a Linear Regression Model

# %%
X = df.iloc[:,:-1]    #independent features
y = df.iloc[:,-1]     #dependent feature

# %% [markdown]
# #### Now let's split the data into a training set and a testing set. We will train out model on the training set and then use the test set to evaluate the model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.33,random_state = 50)

print(X_train.shape)
print(X_test.shape)
# Out:
# (339, 13)
# (167, 13)

# %% [markdown]
# ### Creating and training model

# %%
from sklearn.linear_model import LinearRegression

# %%
linreg = LinearRegression()
linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel("Prices")
plt.ylabel("Predicted prices")
# Out:
# Text(0, 0.5, 'Predicted prices')
